# %%
# !pip install pymongo

# %%
import pymongo

myclient = pymongo.MongoClient('mongodb+srv://vishaliuma309:vis301@cluster0.xdkf2lu.mongodb.net/?retryWrites=true&w=majority')
mydb = myclient["sample_airbnb"]
mycol = mydb["listingsAndReviews"]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df_data = mycol.find()

df = pd.DataFrame(df_data)
df
# Out:
#            _id                            listing_url  \
# 0     10059244  https://www.airbnb.com/rooms/10059244
# 1     10069642  https://www.airbnb.com/rooms/10069642
# 2      1001265   https://www.airbnb.com/rooms/1001265
# 3     10021707  https://www.airbnb.com/rooms/10021707
# 4     10057447  https://www.airbnb.com/rooms/10057447
# ...        ...                                    ...
# 5550   9944044   https://www.airbnb.com/rooms/9944044
# 5551   9853331   https://www.airbnb.com/rooms/9853331
# 5552   9895628   https://www.airbnb.com/rooms/9895628
# 5553   9937100   https://www.airbnb.com/rooms/9937100
# 5554   9993190   https://www.airbnb.com/rooms/9993190
#
#                                                    name  \
# 0      Ligne verte - à 15 min de métro du centre ville.
# 1                    Ótimo Apto proximo Parque Olimpico
# 2                      Ocean View Waikiki Marina w/prkg
# 3                              Private Room in Bushwick
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 42 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _id                    5555 non-null   object
#  1   listing_url            5555 non-null   object
#  2   name                   5555 non-null   object
#  3   summary                5555 non-null   object
#  4   space                  5555 non-null   object
#  5   description            5555 non-null   object
#  6   neighborhood_overview  5555 non-null   object
#  7   notes                  5555 non-null   object
#  8   transit                5555 non-null   object
#  9   access                 5555 non-null   object
#  10  interaction            5555 non-null   object
#  11  house_rules            5555 non-null   object
#  12  property_type          5555 non-null   object
#  13  room_type              5555 non-null   object
# ...

# %%
df.describe()
# Out:
#        accommodates     bedrooms         beds  number_of_reviews  \
# count   5555.000000  5550.000000  5542.000000        5555.000000
# mean       3.505851     1.411712     2.071454          27.606481
# std        2.297019     1.041942     1.619660          49.798376
# min        1.000000     0.000000     0.000000           0.000000
# 25%        2.000000     1.000000     1.000000           1.000000
# 50%        3.000000     1.000000     2.000000           5.000000
# 75%        4.000000     2.000000     3.000000          32.000000
# max       16.000000    20.000000    25.000000         533.000000
#
#        reviews_per_month
# count          94.000000
# mean            1.712766
# std             1.492795
# min             1.000000
# 25%             1.000000
# 50%             1.000000
# 75%             2.000000
# max            10.000000

# %%
df.duplicated().sum()

# %%
df.isnull().sum()
# Out:
# _id                         0
# listing_url                 0
# name                        0
# summary                     0
# space                       0
# description                 0
# neighborhood_overview       0
# notes                       0
# transit                     0
# access                      0
# interaction                 0
# house_rules                 0
# property_type               0
# room_type                   0
# bed_type                    0
# minimum_nights              0
# maximum_nights              0
# cancellation_policy         0
# last_scraped                0
# calendar_last_scraped       0
# accommodates                0
# bedrooms                    5
# beds                       13
# number_of_reviews           0
# bathrooms                  10
# amenities                   0
# price                       0
# extra_people                0
# guests_included             0
# images                      0
# host                        0
# ...

# %%
df.shape
# Out:
# (5555, 42)

# %%
import numpy as np
df['bathrooms'] = df['bathrooms'].apply(np.float64(df['bathrooms']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-120-0668db6d09ef> in <cell line: 2>()
#       1 import numpy as np
# ----> 2 df['bathrooms'] = df['bathrooms'].apply(np.float64(df['bathrooms']))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __array__(self, dtype)
#     891               dtype='datetime64[ns]')
#     892         """
# --> 893         return np.asarray(self._values, dtype)
#     894
#     895     # ----------------------------------------------------------------------
#
# TypeError: float() argument must be a string or a real number, not 'Decimal128'

# %%
sns.boxplot(df['bedrooms'])
# Out:
# <Axes: >

# %%
df['bedrooms'] = df['bedrooms'].fillna(df['bedrooms'].median())

# %%
sns.boxplot(df['beds'])
# Out:
# <Axes: >

# %%
df['beds'] = df['beds'].fillna(df['beds'].median())

# %%
sns.hist(df['bathrooms'])

# %%
df['bathrooms'].value_counts()
# Out:
# 1.0     4202
# 2.0      774
# 1.5      231
# 3.0      132
# 2.5       79
# 4.0       33
# 3.5       26
# 0.5       15
# 0.0       14
# 5.0       11
# 4.5        8
# 7.0        6
# 8.0        5
# 6.0        5
# 5.5        2
# 16.0       1
# 9.0        1
# Name: bathrooms, dtype: int64

# %%
df['bathrooms'] = df['bathrooms'].fillna(1.0)

# %%
df['security_deposit'].value_counts()
# Out:
# 0.00       1275
# 500.00      308
# 200.00      272
# 300.00      209
# 100.00      201
#            ...
# 1689.00       1
# 1250.00       1
# 206.00        1
# 6528.00       1
# 850.00        1
# Name: security_deposit, Length: 213, dtype: int64

# %%
df['security_deposit'] = df['security_deposit'].fillna(0.00)

# %%
df['cleaning_fee'].value_counts()
# Out:
# 0.00      400
# 50.00     297
# 100.00    215
# 150.00    209
# 20.00     202
#          ...
# 4.00        1
# 54.00       1
# 424.00      1
# 385.00      1
# 315.00      1
# Name: cleaning_fee, Length: 291, dtype: int64

# %%
df['cleaning_fee'] = df['cleaning_fee'].fillna(0.00)

# %%
df['last_review'].value_counts()
# Out:
# 2019-01-01 05:00:00    92
# 2019-01-02 05:00:00    91
# 2019-03-03 05:00:00    86
# 2019-02-24 05:00:00    84
# 2019-02-17 05:00:00    77
#                        ..
# 2017-09-18 04:00:00     1
# 2018-06-09 04:00:00     1
# 2016-02-12 05:00:00     1
# 2017-08-15 04:00:00     1
# 2016-06-12 04:00:00     1
# Name: last_review, Length: 809, dtype: int64

# %%
import numpy as np

plt.hist(df['last_review'])

Q1 = np.percentile(df['last_review'], 25)
Q3 = np.percentile(df['last_review'], 75)
IQR = Q3 - Q1

threshold = 1.5 * IQR

outliers = df['last_review'][(df['last_review'] < Q1 - threshold) | (df['last_review'] > Q3 + threshold)]

plt.scatter(outliers, np.zeros_like(outliers), color='green', label='Outliers')

plt.legend()
plt.show()

# %%
df['weekly_price'].value_counts()
# Out:
# 600.00     25
# 500.00     23
# 400.00     18
# 700.00     17
# 1000.00    16
#            ..
# 810.00      1
# 6702.00     1
# 8934.00     1
# 1004.00     1
# 4888.00     1
# Name: weekly_price, Length: 323, dtype: int64

# %%
weekly_price = df['weekly_price'].values

# weekly_price = int(weekly_price)
print(type(weekly_price))
print(weekly_price)
# Out:
# <class 'numpy.ndarray'>
# [nan nan Decimal128('650.00') ... nan nan nan]

# %% [markdown]
# # Host Data

# %%
host_data = mycol.find({}, {"host": 1, "_id": 1, "name": 1})

host_df = pd.json_normalize(list(host_data))

host_df
# Out:
#            _id                                               name  \
# 0     10059244   Ligne verte - à 15 min de métro du centre ville.
# 1     10069642                 Ótimo Apto proximo Parque Olimpico
# 2      1001265                   Ocean View Waikiki Marina w/prkg
# 3     10021707                           Private Room in Bushwick
# 4     10057447                     Modern Spacious 1 Bedroom Loft
# ...        ...                                                ...
# 5550   9944044                                 Sanctuary Bundeena
# 5551   9853331                        Amazing apartment in LEBLON
# 5552   9895628                Duplex com vista para o J. Botanico
# 5553   9937100                Frida's Centric&Stylish Studio Apt.
# 5554   9993190  Just Steps from the Ocean at Premier Platinum ...
#
#      host.host_id                               host.host_url  host.host_name  \
# 0         7140229   https://www.airbnb.com/users/show/7140229            Caro
# ...

# %%
host_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   _id                             5555 non-null   object
#  1   name                            5555 non-null   object
#  2   host.host_id                    5555 non-null   object
#  3   host.host_url                   5555 non-null   object
#  4   host.host_name                  5555 non-null   object
#  5   host.host_location              5555 non-null   object
#  6   host.host_about                 5555 non-null   object
#  7   host.host_response_time         4167 non-null   object
#  8   host.host_thumbnail_url         5555 non-null   object
#  9   host.host_picture_url           5555 non-null   object
#  10  host.host_neighbourhood         5555 non-null   object
#  11  host.host_response_rate         4167 non-null   float64
# ...

# %%
host_df.isnull().sum()
# Out:
# _id                                  0
# name                                 0
# host.host_id                         0
# host.host_url                        0
# host.host_name                       0
# host.host_location                   0
# host.host_about                      0
# host.host_response_time           1388
# host.host_thumbnail_url              0
# host.host_picture_url                0
# host.host_neighbourhood              0
# host.host_response_rate              0
# host.host_is_superhost               0
# host.host_has_profile_pic            0
# host.host_identity_verified          0
# host.host_listings_count             0
# host.host_total_listings_count       0
# host.host_verifications              0
# dtype: int64

# %%
h = host_df.dropna()

# %%
sns.boxplot(host_df['host.host_response_rate'])
# Out:
# <Axes: >

# %%
host_df['host.host_response_rate'] = host_df['host.host_response_rate'].fillna(host_df['host.host_response_rate'].median())

# %% [markdown]
# # Address

# %%
address_data = mycol.find({}, {"address": 1, "_id": 1, "name": 1})

address_df = pd.json_normalize(list(address_data))

address_df
# Out:
#            _id                                               name  \
# 0     10059244   Ligne verte - à 15 min de métro du centre ville.
# 1     10069642                 Ótimo Apto proximo Parque Olimpico
# 2      1001265                   Ocean View Waikiki Marina w/prkg
# 3     10021707                           Private Room in Bushwick
# 4     10057447                     Modern Spacious 1 Bedroom Loft
# ...        ...                                                ...
# 5550   9944044                                 Sanctuary Bundeena
# 5551   9853331                        Amazing apartment in LEBLON
# 5552   9895628                Duplex com vista para o J. Botanico
# 5553   9937100                Frida's Centric&Stylish Studio Apt.
# 5554   9993190  Just Steps from the Ocean at Premier Platinum ...
#
#                               address.street            address.suburb  \
# 0                   Montréal, Québec, Canada     Hochelaga-Maisonneuve
# ...

# %%
address_df.isnull().sum()
# Out:
# _id                                   0
# name                                  0
# address.street                        0
# address.suburb                        0
# address.government_area               0
# address.market                        0
# address.country                       0
# address.country_code                  0
# address.location.type                 0
# address.location.coordinates          0
# address.location.is_location_exact    0
# dtype: int64

# %%
address_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 11 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   _id                                 5555 non-null   object
#  1   name                                5555 non-null   object
#  2   address.street                      5555 non-null   object
#  3   address.suburb                      5555 non-null   object
#  4   address.government_area             5555 non-null   object
#  5   address.market                      5555 non-null   object
#  6   address.country                     5555 non-null   object
#  7   address.country_code                5555 non-null   object
#  8   address.location.type               5555 non-null   object
#  9   address.location.coordinates        5555 non-null   object
#  10  address.location.is_location_exact  5555 non-null   bool
# dtypes: bool(1), object(10)
# ...

# %%
address_df.describe()
# Out:
#              _id  name            address.street address.suburb  \
# count       5555  5555                      5555           5555
# unique      5555  5538                       677            410
# top     10059244        Montréal, Québec, Canada
# freq           1     8                       492            887
#
#                                   address.government_area address.market  \
# count                                                5555           5555
# unique                                                418             15
# top     Cedofeita, Ildefonso, Sé, Miragaia, Nicolau, V...       Istanbul
# freq                                                  275            660
#
#        address.country address.country_code address.location.type  \
# count             5555                 5555                  5555
# unique               9                    9                     1
# top      United States                   US                 Point
# ...

# %% [markdown]
# # Review Score

# %%
review_score_data = mycol.find({}, {"review_scores": 1, "_id": 1, "name": 1})

review_score_df = pd.json_normalize(list(review_score_data))

review_score_df
# Out:
#            _id                                               name  \
# 0     10059244   Ligne verte - à 15 min de métro du centre ville.
# 1     10069642                 Ótimo Apto proximo Parque Olimpico
# 2      1001265                   Ocean View Waikiki Marina w/prkg
# 3     10021707                           Private Room in Bushwick
# 4     10057447                     Modern Spacious 1 Bedroom Loft
# ...        ...                                                ...
# 5550   9944044                                 Sanctuary Bundeena
# 5551   9853331                        Amazing apartment in LEBLON
# 5552   9895628                Duplex com vista para o J. Botanico
# 5553   9937100                Frida's Centric&Stylish Studio Apt.
# 5554   9993190  Just Steps from the Ocean at Premier Platinum ...
#
#       review_scores.review_scores_accuracy  \
# 0                                      NaN
# 1                                      NaN
# ...

# %%
review_score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5555 entries, 0 to 5554
# Data columns (total 9 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   _id                                        5555 non-null   object
#  1   name                                       5555 non-null   object
#  2   review_scores.review_scores_accuracy       4079 non-null   float64
#  3   review_scores.review_scores_cleanliness    4082 non-null   float64
#  4   review_scores.review_scores_checkin        4080 non-null   float64
#  5   review_scores.review_scores_communication  4081 non-null   float64
#  6   review_scores.review_scores_location       4081 non-null   float64
#  7   review_scores.review_scores_value          4080 non-null   float64
#  8   review_scores.review_scores_rating         4081 non-null   float64
# dtypes: float64(7), object(2)
# memory usage: 390.7+ KB

# %%
review_score_df.isnull().sum()
# Out:
# _id                                          0
# name                                         0
# review_scores.review_scores_accuracy         0
# review_scores.review_scores_cleanliness      0
# review_scores.review_scores_checkin          0
# review_scores.review_scores_communication    0
# review_scores.review_scores_location         0
# review_scores.review_scores_value            0
# review_scores.review_scores_rating           0
# dtype: int64

# %%
sns.boxplot(review_score_df['review_scores.review_scores_accuracy'])
# Out:
# <Axes: >

# %%
review_score_df['review_scores.review_scores_accuracy'] = review_score_df['review_scores.review_scores_accuracy'].fillna(review_score_df['review_scores.review_scores_accuracy'].median())

# %%
sns.boxplot(review_score_df['review_scores.review_scores_cleanliness'])
# Out:
# <Axes: >

# %%
review_score_df['review_scores.review_scores_cleanliness'] = review_score_df['review_scores.review_scores_cleanliness'].fillna(review_score_df['review_scores.review_scores_cleanliness'].median())

# %%
sns.boxplot(review_score_df['review_scores.review_scores_communication'])
# Out:
# <Axes: >

# %%
review_score_df['review_scores.review_scores_communication'] = review_score_df['review_scores.review_scores_communication'].fillna(review_score_df['review_scores.review_scores_communication'].median())

# %%
sns.boxplot(review_score_df['review_scores.review_scores_checkin'])
# Out:
# <Axes: >

# %%
review_score_df['review_scores.review_scores_checkin'] = review_score_df['review_scores.review_scores_checkin'].fillna(review_score_df['review_scores.review_scores_checkin'].median())

# %%
sns.boxplot(review_score_df['review_scores.review_scores_location'])
# Out:
# <Axes: >

# %%
review_score_df['review_scores.review_scores_location'] = review_score_df['review_scores.review_scores_location'].fillna(review_score_df['review_scores.review_scores_location'].median())

# %%
sns.boxplot(review_score_df['review_scores.review_scores_value'])
# Out:
# <Axes: >

# %%
review_score_df['review_scores.review_scores_value'] = review_score_df['review_scores.review_scores_value'].fillna(review_score_df['review_scores.review_scores_value'].median())

# %%
sns.boxplot(review_score_df['review_scores.review_scores_rating'])
# Out:
# <Axes: >

# %%
review_score_df['review_scores.review_scores_rating'] = review_score_df['review_scores.review_scores_rating'].fillna(review_score_df['review_scores.review_scores_rating'].median())

# %% [markdown]
# # SQlite3 Connection

# %%
import sqlite3
import pandas as pd

connection = sqlite3.connect('airbnb.db')
cursor = connection.cursor()

# %%
lis_table = 'listing'
lis_columns = ['_id', 'listing_url', 'name', 'summary', 'space', 'description',
       'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
       'house_rules', 'property_type', 'room_type', 'bed_type',
       'minimum_nights', 'maximum_nights', 'cancellation_policy',
       'last_scraped', 'calendar_last_scraped', 'accommodates', 'bedrooms',
       'beds', 'number_of_reviews', 'bathrooms', 'amenities', 'price',
       'extra_people', 'guests_included']

# create_table_query = f"CREATE TABLE IF NOT EXISTS {lis_table} ({', '.join([f'{col} TEXT' for col in lis_columns])})"
# cursor.execute(create_table_query)

# connection.commit()

for index, row in df.iterrows():
    values = tuple(row[lis_columns])
    query = f"INSERT INTO {lis_table} ({', '.join(lis_columns)}) VALUES ({', '.join(['?'] * len(lis_columns))})"
    cursor.execute(query, values)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-110-5572201faf83> in <cell line: 15>()
#      16     values = tuple(row[lis_columns])
#      17     query = f"INSERT INTO {lis_table} ({', '.join(lis_columns)}) VALUES ({', '.join(['?'] * len(lis_columns))})"
# ---> 18     cursor.execute(query, values)
#
# InterfaceError: Error binding parameter 18 - probably unsupported type.

# %%
df.to_sql('listing', connection, index=False, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# <ipython-input-6-2201375304df> in <cell line: 1>()
# ----> 1 df.to_sql('listing', connection, index=False, if_exists='replace')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2985         from pandas.io import sql
#    2986
# -> 2987         return sql.to_sql(
#    2988             self,
#    2989             name,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     693         )
#     694
# --> 695     return pandas_sql.to_sql(
#     696         frame,
#     697         name,
#
# ...

# %%
# Import the numpy library
import numpy as np

# Define a function to convert decimal128 values to float
def convert_decimal_to_float(value):
    try:
        return np.float64(value)
    except (ValueError, TypeError):
        return None

# Apply the conversion function to the column
df['bathrooms'] = df['bathrooms'].apply(convert_decimal_to_float)
